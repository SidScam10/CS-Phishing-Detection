# %%
import hashlib
import os
import email
from bs4 import BeautifulSoup
import re
import json
import requests
from urllib.parse import urlparse, quote
from urlextract import URLExtract
import pandas as pd
import joblib
# Import the custom classes from the separate file to avoid retraining
from model_classes import SenderPatternFeatures, URLFeatureExtractor
# Load all API Keys from .env file
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
EML_DIR = 'emails/'
WHITELIST_FILE = 'whitelist.json'
PHISHTANK_API_URL = "https://checkurl.phishtank.com/checkurl/"
USER_AGENT = "phishtank/PhishDet"

PHISHTANK_API_KEY = "" # Blank

# %%
# Add this for VirusTotal
VIRUSTOTAL_API_KEY = os.getenv("VIRUSTOTAL_API_KEY")
VIRUSTOTAL_URL = "https://www.virustotal.com/api/v3/files/"

# %%
def load_whitelist(filepath):
    with open(filepath, 'r') as f:
        whitelist = json.load(f)
    return whitelist

# %%
def is_whitelisted(url, whitelist):
    parsed = urlparse(url)
    domain = parsed.netloc

    # Exact URL match
    if url in whitelist.get('exactMatching', {}).get('url', []):
        return True

    # Domain matches
    for whitelisted_domain in whitelist.get('exactMatching', {}).get('domain', []):
        if whitelisted_domain in domain:
            return True

    # Domains in URLs
    for domain_substring in whitelist.get('domainsInURLs', []):
        if domain_substring in domain:
            return True

    return False

# %%
def check_phishtank(url):
    headers = {'User-Agent': USER_AGENT}
    payload = {
        'url': url,  # Do NOT encode with quote()
        'format': 'json'
    }
    if PHISHTANK_API_KEY:
        payload['app_key'] = PHISHTANK_API_KEY

    try:
        response = requests.post(PHISHTANK_API_URL, data=payload, headers=headers, timeout=10)
        print(f"Querying PhishTank for: {url}")
        print(f"Status code: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            print(f"PhishTank response: {data}")
            results = data.get('results', {})
            in_database = results.get('in_database', False)
            verified = results.get('verified', False)
            valid = results.get('valid', False)

            if in_database and verified and valid:
                return 'malicious'
            elif in_database and not verified:
                return 'suspicious'
            else:
                # URL not in database - treat as unknown, not safe
                return 'unknown'
        else:
            print(f"⚠️ API call failed: {response.status_code}")
            return 'unknown'
    except Exception as e:
        print(f"⚠️ Error querying PhishTank: {e}")
        return 'unknown'

# %%
def parse_emails(filepath):
    with open(filepath, 'rb') as f:
        raw_email = f.read()
    
    msg = email.message_from_bytes(raw_email)

    #Extract subject
    subject_header = msg['Subject']
    if subject_header:
        subject_decoded = email.header.decode_header(subject_header)
        subject = ''
        for fragment, encoding in subject_decoded:
            if isinstance(fragment, bytes):
                try:
                    subject += fragment.decode(encoding or 'utf-8', errors='replace')
                except LookupError:
                    subject += fragment.decode('utf-8', errors='replace')
            else:
                subject += fragment
    else:
        subject = '(No Subject)'

    #extract from address
    from_addr = email.utils.parseaddr(msg.get('From'))[1]

    #Extract body
    body = ''
    for part in msg.walk():
        content_type = part.get_content_type()
        if content_type == 'text/plain':
            try:
                body += part.get_payload(decode=True).decode(errors='replace')
            except:
                continue
        elif content_type == 'text/html':
            try:
                html = part.get_payload(decode=True).decode(errors='replace')
                soup = BeautifulSoup(html, 'html.parser')
                body += soup.get_text()
            except:
                continue
    
    # Extract URLs using regex
    extractor = URLExtract()
    urls = extractor.find_urls(body)

    return from_addr, subject, body, urls, msg

# %%
def extract_attachments(msg, save_dir='attachments'):
    attachments = []
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    for part in msg.walk():
        if part.get_content_maintype() == 'multipart':
            continue
        if part.get('Content-Disposition') is None:
            continue

        filename = part.get_filename()
        if filename:
            # Clean filename to avoid path issues
            safe_filename = re.sub(r'[<>:"/\\|?*]', '_', filename)
            filepath = os.path.join(save_dir, safe_filename)
            try:
                with open(filepath, "wb") as f:
                    f.write(part.get_payload(decode=True))
                attachments.append(filepath)
            except Exception as e:
                print(f"⚠️ Error saving attachment {filename}: {e}")
    return attachments

# %%
def get_file_sha256(filepath):
    sha256_hash = hashlib.sha256()
    with open(filepath, "rb") as f:
        for byte_block in iter(lambda: f.read(4096), b""):
            sha256_hash.update(byte_block)
    return sha256_hash.hexdigest()

# %%
def check_virustotal(file_hash):
    headers = {
        "x-apikey": VIRUSTOTAL_API_KEY
    }
    url = VIRUSTOTAL_URL + file_hash
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            stats = data['data']['attributes']['last_analysis_stats']
            malicious_count = stats.get('malicious', 0)
            if malicious_count > 0:
                return 'malicious'
            else:
                return 'safe'
        elif response.status_code == 404:
            return 'unknown'  # File not found in VT database
        else:
            print(f"⚠️ VirusTotal API error: {response.status_code}")
            return 'unknown'
    except Exception as e:
        print(f"⚠️ Error checking VirusTotal: {e}")
        return 'unknown'

# %%
def ml_detection_check(from_addr, subject, body, urls):
    """
    Use ML model to detect phishing emails when blacklist checks fail
    """
    try:
        # Load the trained model
        model = joblib.load("phishing_email_model_fixed.pkl")
        
        # Prepare data for ML model
        email_data = {
            'subject': subject,
            'body': body,
            'sender': from_addr,
            'urls': len(urls)
        }
        
        # Create DataFrame for prediction
        test_df = pd.DataFrame([email_data])
        
        # Make prediction
        prediction = model.predict(test_df)[0]
        prediction_proba = model.predict_proba(test_df)[0]
        confidence = max(prediction_proba) * 100
        
        # Determine result
        result = "PHISHING" if prediction == 1 else "LEGITIMATE"
        
        return result, confidence
        
    except Exception as e:
        print(f"⚠️ Error in ML detection: {e}")
        return "ERROR", 0

# %%
if __name__ == '__main__':
    whitelist = load_whitelist(WHITELIST_FILE)

    # Check for .eml files in the directory
    if not os.path.exists(EML_DIR):
        print(f"📁 Directory '{EML_DIR}' does not exist. Please create it and add your .eml files.")
    else:
        eml_files = [f for f in os.listdir(EML_DIR) if f.endswith('.eml')]
        if not eml_files:
            print(f"⚠️ No .eml files found in '{EML_DIR}'. Please add some emails for analysis.")
        else:
            for eml_file in eml_files:
                filepath = os.path.join(EML_DIR, eml_file)
                from_addr, subject, body, urls, msg = parse_emails(filepath)
                print(f"📧 File: {eml_file}")
                print(f"From: {from_addr}")
                print(f"Subject: {subject}")
                
                # Track overall email status
                email_status = "SAFE"
                blacklist_failed = False
                
                print("🔍 BLACKLIST ANALYSIS:")
                print("Extracted URLs:")
                for url in urls:
                    print(f"  - {url}")
                    if is_whitelisted(url, whitelist):
                        print("    ✅ Whitelisted — skipping analysis.")
                        continue
                    status = check_phishtank(url)
                    if status == 'malicious':
                        print("    ⚠️ Malicious URL detected!")
                        email_status = "MALICIOUS"
                    elif status == 'suspicious':
                        print("    ⚠️ Suspicious URL detected!")
                        email_status = "MALICIOUS"
                    elif status == 'unknown':
                        print("    ❓ URL not in database - requires ML analysis.")
                        blacklist_failed = True
                    else:
                        print("    ⚠️ Unknown status.")
                        blacklist_failed = True
                
                # --- Attachment checking ---
                attachments = extract_attachments(msg)
                if attachments:
                    print("Attachments found:")
                    for attachment in attachments:
                        file_hash = get_file_sha256(attachment)
                        status = check_virustotal(file_hash)
                        if status == 'malicious':
                            print(f"  ⚠️ Malicious attachment detected: {attachment}")
                            email_status = "MALICIOUS"
                        elif status == 'safe':
                            print(f"  ✅ Attachment is safe: {attachment}")
                        else:
                            print(f"  ⚠️ File Not Found in VirusTotal Database (Unknown): {attachment}")
                            blacklist_failed = True
                else:
                    print("No attachments found.")
                
                # --- ML Detection as Fallback ---
                if email_status != "MALICIOUS" and blacklist_failed:
                    print("\n🤖 ML DETECTION (Fallback):")
                    ml_result, confidence = ml_detection_check(from_addr, subject, body, urls)
                    if ml_result == "PHISHING":
                        print(f"    ⚠️ ML Model detected PHISHING (Confidence: {confidence:.2f}%)")
                        email_status = "MALICIOUS"
                    elif ml_result == "LEGITIMATE":
                        print(f"    ✅ ML Model detected LEGITIMATE (Confidence: {confidence:.2f}%)")
                    else:
                        print(f"    ⚠️ ML detection error")
                
                # Final verdict
                print(f"\n🎯 FINAL VERDICT: {email_status}")
                if email_status == "MALICIOUS":
                    print("    🚨 EMAIL IS MALICIOUS - TAKE ACTION!")
                else:
                    print("    ✅ Email appears to be safe")
                
                print("\n" + "-"*60 + "\n")
# Out:
# 📧 File: sample-1.eml
# From: banco.bradesco@atendimento.com.br
# Subject: CLIENTE PRIME - BRADESCO LIVELO: Seu cartão tem 92.990 pontos LIVELO expirando hoje!
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-10.eml
# From:
# Subject: Microsoft account unusual signin activity
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
#   - sign.in
# Querying PhishTank for: sign.in
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:01+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a4d013610.04940116'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
#   - 103.225.77.255
# Querying PhishTank for: 103.225.77.255
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:02+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a4e5240d0.59988683'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
# No attachments found.
#
# 🤖 ML DETECTION (Fallback):
#     ✅ ML Model detected LEGITIMATE (Confidence: 70.60%)
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-100.eml
# From: zonnepaneel@appjj.serenitepure.fr
# Subject: 🔋 Zonnepanelen voor een goede prijs
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-11.eml
# From: contact@123gereedschap.nl
# Subject: 💕 Bekijk deze mail alleen als je volwassen bent
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-12.eml
# From: do-not-reply@ses.binance.com
# Subject: [Binаnсе] lmmediate verification required for rodrigo-f-p@hotmail.com
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-13.eml
# From: do-not-reply@ses.binance.com
# Subject: [Binаnсе] lmmediate verification required for rodrigo-f-p@hotmail.com
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-14.eml
# From: registration@and.co.uk
# Subject: Massive 400% Welcome Offer + 50 free spins awaits you when you open your account.
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-15.eml
# From: 87357344@mymts.net
# Subject: [## Metamask ##] You have a new update
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-16.eml
# From: makarifulislamkariful24599+NMwGO8qDiD8HKv6RyvtRa6ND11@gmail.com
# Subject: OrderConfirmation:93345881
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-17.eml
# From: ledger@secureliveupdates.com
# Subject: [29th, August] Reminder from Ledger
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
#   - https://links.ledger.com/e/evib?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=mksJhyDPhO6KuQX6z_JqQ0vxXFI9cwDcg-sSZj1NufV2NqLOP2AZ_KqQdhKDuwYwdSV5eXxmorKjhtCwGkiIgiqTMl_nBUdzOFwpAzX8Nc-5o2wIcTphaaYQ3bJOORQv
# Querying PhishTank for: https://links.ledger.com/e/evib?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=mksJhyDPhO6KuQX6z_JqQ0vxXFI9cwDcg-sSZj1NufV2NqLOP2AZ_KqQdhKDuwYwdSV5eXxmorKjhtCwGkiIgiqTMl_nBUdzOFwpAzX8Nc-5o2wIcTphaaYQ3bJOORQv
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:04+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a501a6f16.94462637'}, 'results': {'url': 'https://links.ledger.com/e/evib?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=mksJhyDPhO6KuQX6z_JqQ0vxXFI9cwDcg-sSZj1NufV2NqLOP2AZ_KqQdhKDuwYwdSV5eXxmorKjhtCwGkiIgiqTMl_nBUdzOFwpAzX8Nc-5o2wIcTphaaYQ3bJOORQv', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd90HNgic7VsnHLNCR7Q7_fNgS2q7BGsxaeI3fNtst5CLC7rsMadQBia4wv6pIEqErjC8EtMgSGU5m7IKCCd1HgYDed6rYl4B0pCaBenqoDmf0Ad2NmrNYvwY-gcEotZS0C90LJUka7fnCqoAy99KLGdMQRO1mYtA34QT7TDUlj_5_aXc40yruDtB0FgBXkiFI2L5sekF5DnM1tuVoQ8NtYEBN_xP6zb2Fc2nwcTshVe335Bk1c40rDJ3IjN4HSu-Zyx41Jd9_TVFFyWqBjqL--auMozLIqu5WaU8gkmYXGKaESOgG8FBqXlqT76MIT1gfRe-wxpJdNo_6OoGYtHr4m0%3D
# Querying PhishTank for: https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd90HNgic7VsnHLNCR7Q7_fNgS2q7BGsxaeI3fNtst5CLC7rsMadQBia4wv6pIEqErjC8EtMgSGU5m7IKCCd1HgYDed6rYl4B0pCaBenqoDmf0Ad2NmrNYvwY-gcEotZS0C90LJUka7fnCqoAy99KLGdMQRO1mYtA34QT7TDUlj_5_aXc40yruDtB0FgBXkiFI2L5sekF5DnM1tuVoQ8NtYEBN_xP6zb2Fc2nwcTshVe335Bk1c40rDJ3IjN4HSu-Zyx41Jd9_TVFFyWqBjqL--auMozLIqu5WaU8gkmYXGKaESOgG8FBqXlqT76MIT1gfRe-wxpJdNo_6OoGYtHr4m0%3D
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:05+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a517ba339.06033760'}, 'results': {'url': 'https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd90HNgic7VsnHLNCR7Q7_fNgS2q7BGsxaeI3fNtst5CLC7rsMadQBia4wv6pIEqErjC8EtMgSGU5m7IKCCd1HgYDed6rYl4B0pCaBenqoDmf0Ad2NmrNYvwY-gcEotZS0C90LJUka7fnCqoAy99KLGdMQRO1mYtA34QT7TDUlj_5_aXc40yruDtB0FgBXkiFI2L5sekF5DnM1tuVoQ8NtYEBN_xP6zb2Fc2nwcTshVe335Bk1c40rDJ3IjN4HSu-Zyx41Jd9_TVFFyWqBjqL--auMozLIqu5WaU8gkmYXGKaESOgG8FBqXlqT76MIT1gfRe-wxpJdNo_6OoGYtHr4m0=', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMh2RkojZbw00SZ-m_xkGJjRNLtXQGVsoQW9jcaDkiqREcvZziVBqdOHKKHqG5d5wJZ8OYQfZ69Tt2kg0yUYlyPAY_pg75drS2dw8QNVFLKsHE6BL2Mu0TPZuOa-fetnSNN4rms7CSIjU7fiBYRzz0VuNVogtx8dnnEBD8yT1RoLlI8rqgRrKhv2jGWzSYujJqTZdK2cnE8M7PLX6llVArtc%3D
# Querying PhishTank for: https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMh2RkojZbw00SZ-m_xkGJjRNLtXQGVsoQW9jcaDkiqREcvZziVBqdOHKKHqG5d5wJZ8OYQfZ69Tt2kg0yUYlyPAY_pg75drS2dw8QNVFLKsHE6BL2Mu0TPZuOa-fetnSNN4rms7CSIjU7fiBYRzz0VuNVogtx8dnnEBD8yT1RoLlI8rqgRrKhv2jGWzSYujJqTZdK2cnE8M7PLX6llVArtc%3D
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:06+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a52489cc3.53717978'}, 'results': {'url': 'https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMh2RkojZbw00SZ-m_xkGJjRNLtXQGVsoQW9jcaDkiqREcvZziVBqdOHKKHqG5d5wJZ8OYQfZ69Tt2kg0yUYlyPAY_pg75drS2dw8QNVFLKsHE6BL2Mu0TPZuOa-fetnSNN4rms7CSIjU7fiBYRzz0VuNVogtx8dnnEBD8yT1RoLlI8rqgRrKhv2jGWzSYujJqTZdK2cnE8M7PLX6llVArtc=', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://sites.google.com/view/ledger-live/ledger-live-winx86-upgrade
#     ✅ Whitelisted — skipping analysis.
#   - https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMnHxLZyA3U1bEw6uiFGJ9L4YaHYST2dHha9CJrVxQCgs-Sj1xJzuv6dpoJbMVfEiEwTqZC8ZzXvTwGO1etct-aN3xUAyzGD5Pc1L_ncyH7XWoRjX4ca3IkcXdJa1j1UZakS7vQRMz5LCTC9q_kvpagFLxeget3dPEzUsEFAg7fd5aA1QwRJawR6T1vpS9t5dZT_bLOgxtnNTE7uOVe1Tkro%3D
# Querying PhishTank for: https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMnHxLZyA3U1bEw6uiFGJ9L4YaHYST2dHha9CJrVxQCgs-Sj1xJzuv6dpoJbMVfEiEwTqZC8ZzXvTwGO1etct-aN3xUAyzGD5Pc1L_ncyH7XWoRjX4ca3IkcXdJa1j1UZakS7vQRMz5LCTC9q_kvpagFLxeget3dPEzUsEFAg7fd5aA1QwRJawR6T1vpS9t5dZT_bLOgxtnNTE7uOVe1Tkro%3D
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:07+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a53ab7879.59637390'}, 'results': {'url': 'https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMnHxLZyA3U1bEw6uiFGJ9L4YaHYST2dHha9CJrVxQCgs-Sj1xJzuv6dpoJbMVfEiEwTqZC8ZzXvTwGO1etct-aN3xUAyzGD5Pc1L_ncyH7XWoRjX4ca3IkcXdJa1j1UZakS7vQRMz5LCTC9q_kvpagFLxeget3dPEzUsEFAg7fd5aA1QwRJawR6T1vpS9t5dZT_bLOgxtnNTE7uOVe1Tkro=', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd-IbFHDvE4lyBdeEwgc1qZXjzWHp-JIvqlP7cL9U0x_2RvcOHS7kLzsM_gXxkz2BpVT4FJoQl7DFENbMw15hDbZyp2FGnwp1ZlphUMOPBnfSzfXHSG_b2OpMSpeq5hIhaeVypVuMqoQSoy5vKbU1pFa7qW2pN7m-tocLoSmI_5Co6Zilh5gf54zdYnSnhLdATLVHfFvqcMblFPsiG0GRDft7wV_HqFTI0LqLhqV3xCj3smH2WyJU2OSaqGSL7eO0Om90DS_x9HkgTB4XYm-aFpQtV2nQW9LVr9DuCxM4DAWNY_KO0ThJW5RSFkl3100B_JDz1rn52QuxVReGam_BqX49Q4S3uOBB16SsM941aPqNm8FKPI_3A9y2j4wg98u79LL09-WzSiU_n0dG7kGwbwC9NeaXOlwZroXVfNPnwEyL
# Querying PhishTank for: https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd-IbFHDvE4lyBdeEwgc1qZXjzWHp-JIvqlP7cL9U0x_2RvcOHS7kLzsM_gXxkz2BpVT4FJoQl7DFENbMw15hDbZyp2FGnwp1ZlphUMOPBnfSzfXHSG_b2OpMSpeq5hIhaeVypVuMqoQSoy5vKbU1pFa7qW2pN7m-tocLoSmI_5Co6Zilh5gf54zdYnSnhLdATLVHfFvqcMblFPsiG0GRDft7wV_HqFTI0LqLhqV3xCj3smH2WyJU2OSaqGSL7eO0Om90DS_x9HkgTB4XYm-aFpQtV2nQW9LVr9DuCxM4DAWNY_KO0ThJW5RSFkl3100B_JDz1rn52QuxVReGam_BqX49Q4S3uOBB16SsM941aPqNm8FKPI_3A9y2j4wg98u79LL09-WzSiU_n0dG7kGwbwC9NeaXOlwZroXVfNPnwEyL
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:09+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a551d4e40.58868252'}, 'results': {'url': 'https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd-IbFHDvE4lyBdeEwgc1qZXjzWHp-JIvqlP7cL9U0x_2RvcOHS7kLzsM_gXxkz2BpVT4FJoQl7DFENbMw15hDbZyp2FGnwp1ZlphUMOPBnfSzfXHSG_b2OpMSpeq5hIhaeVypVuMqoQSoy5vKbU1pFa7qW2pN7m-tocLoSmI_5Co6Zilh5gf54zdYnSnhLdATLVHfFvqcMblFPsiG0GRDft7wV_HqFTI0LqLhqV3xCj3smH2WyJU2OSaqGSL7eO0Om90DS_x9HkgTB4XYm-aFpQtV2nQW9LVr9DuCxM4DAWNY_KO0ThJW5RSFkl3100B_JDz1rn52QuxVReGam_BqX49Q4S3uOBB16SsM941aPqNm8FKPI_3A9y2j4wg98u79LL09-WzSiU_n0dG7kGwbwC9NeaXOlwZroXVfNPnwEyL', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd-IbFHDvE4lyBdeEwgc1qZXjzWHp-JIvqlP7cL9U0x_2RvcOHS7kLzsM_gXxkz2BpVT4FJoQl7DFENbMw15hDbZyp2FGnwp1ZlphUMOPBnfSzfXHSG_b2OpMSpeq5hIhaeVypVuMqoQSoy5vKbU1pFa7qW2pN7m-tocLoSmI_5Co6Zilh5gf54zdYnSnhLdATOVHOgyb9h565LCD6YFJHNhjAOKq9RBTr0R5j2PjNhyszRV_eD7AdXeaT0nJZqFfSRT_DQPqQJSS_9YPYxQx4Ttl15v9ozk8-RSiOMjTuq5fMEPmKKfdb1CKwUFrza6RDt_1r_Fy1Fsda4iBzn5Wk-H7zrPTejMABQLxE9tnUdy4SKALyxx_tAqeyCEzPjGibPAxBphq18DbEOEXT3WvinjwlcFRNZf1OsxI9lskZ6yN
# Querying PhishTank for: https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd-IbFHDvE4lyBdeEwgc1qZXjzWHp-JIvqlP7cL9U0x_2RvcOHS7kLzsM_gXxkz2BpVT4FJoQl7DFENbMw15hDbZyp2FGnwp1ZlphUMOPBnfSzfXHSG_b2OpMSpeq5hIhaeVypVuMqoQSoy5vKbU1pFa7qW2pN7m-tocLoSmI_5Co6Zilh5gf54zdYnSnhLdATOVHOgyb9h565LCD6YFJHNhjAOKq9RBTr0R5j2PjNhyszRV_eD7AdXeaT0nJZqFfSRT_DQPqQJSS_9YPYxQx4Ttl15v9ozk8-RSiOMjTuq5fMEPmKKfdb1CKwUFrza6RDt_1r_Fy1Fsda4iBzn5Wk-H7zrPTejMABQLxE9tnUdy4SKALyxx_tAqeyCEzPjGibPAxBphq18DbEOEXT3WvinjwlcFRNZf1OsxI9lskZ6yN
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:10+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a5686b8f8.72135762'}, 'results': {'url': 'https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd-IbFHDvE4lyBdeEwgc1qZXjzWHp-JIvqlP7cL9U0x_2RvcOHS7kLzsM_gXxkz2BpVT4FJoQl7DFENbMw15hDbZyp2FGnwp1ZlphUMOPBnfSzfXHSG_b2OpMSpeq5hIhaeVypVuMqoQSoy5vKbU1pFa7qW2pN7m-tocLoSmI_5Co6Zilh5gf54zdYnSnhLdATOVHOgyb9h565LCD6YFJHNhjAOKq9RBTr0R5j2PjNhyszRV_eD7AdXeaT0nJZqFfSRT_DQPqQJSS_9YPYxQx4Ttl15v9ozk8-RSiOMjTuq5fMEPmKKfdb1CKwUFrza6RDt_1r_Fy1Fsda4iBzn5Wk-H7zrPTejMABQLxE9tnUdy4SKALyxx_tAqeyCEzPjGibPAxBphq18DbEOEXT3WvinjwlcFRNZf1OsxI9lskZ6yN', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd90HNgic7VsnHLNCR7Q7_fNgS2q7BGsxaeI3fNtst5CLC7rsMadQBia4wv6pIEqErjC8EtMgSGU5m7IKCCd1HgYDed6rYl4B0pCaBenqoDmf0Ad2NmrNYvwY-gcEotZS0G5vl9JAAYy_hntLLtvMFxPc8WSzX9WUSPh7-j4f_8PMc4-3aZH9KzcdlJ3uatWTPK-uvi8JWZdzOo8F0uM3xReEbC-vHNz2A-D4-Rfoi-yrJRFlRxC-7gLwwS2EKXwUdsUzB0fppNQcaA_-q_N_wcy-3AobtQpupEgMVdbmNZzzplSJMk1ekz0NV8XvMpb084M2zqH7hDPBCKQQUcsZD-M%3D
# Querying PhishTank for: https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd90HNgic7VsnHLNCR7Q7_fNgS2q7BGsxaeI3fNtst5CLC7rsMadQBia4wv6pIEqErjC8EtMgSGU5m7IKCCd1HgYDed6rYl4B0pCaBenqoDmf0Ad2NmrNYvwY-gcEotZS0G5vl9JAAYy_hntLLtvMFxPc8WSzX9WUSPh7-j4f_8PMc4-3aZH9KzcdlJ3uatWTPK-uvi8JWZdzOo8F0uM3xReEbC-vHNz2A-D4-Rfoi-yrJRFlRxC-7gLwwS2EKXwUdsUzB0fppNQcaA_-q_N_wcy-3AobtQpupEgMVdbmNZzzplSJMk1ekz0NV8XvMpb084M2zqH7hDPBCKQQUcsZD-M%3D
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:11+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a57ddd886.55934535'}, 'results': {'url': 'https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd90HNgic7VsnHLNCR7Q7_fNgS2q7BGsxaeI3fNtst5CLC7rsMadQBia4wv6pIEqErjC8EtMgSGU5m7IKCCd1HgYDed6rYl4B0pCaBenqoDmf0Ad2NmrNYvwY-gcEotZS0G5vl9JAAYy_hntLLtvMFxPc8WSzX9WUSPh7-j4f_8PMc4-3aZH9KzcdlJ3uatWTPK-uvi8JWZdzOo8F0uM3xReEbC-vHNz2A-D4-Rfoi-yrJRFlRxC-7gLwwS2EKXwUdsUzB0fppNQcaA_-q_N_wcy-3AobtQpupEgMVdbmNZzzplSJMk1ekz0NV8XvMpb084M2zqH7hDPBCKQQUcsZD-M=', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://delfinasf.us2.list-manage.com/about?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1
# Querying PhishTank for: https://delfinasf.us2.list-manage.com/about?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:13+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a59501425.34720818'}, 'results': {'url': 'https://delfinasf.us2.list-manage.com/about?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://delfinasf.us2.list-manage.com/unsubscribe?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1
# Querying PhishTank for: https://delfinasf.us2.list-manage.com/unsubscribe?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:14+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a5a1e3c46.02257832'}, 'results': {'url': 'https://delfinasf.us2.list-manage.com/unsubscribe?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://delfinasf.us2.list-manage.com/profile?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1
# Querying PhishTank for: https://delfinasf.us2.list-manage.com/profile?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:15+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a5b8378f1.40183596'}, 'results': {'url': 'https://delfinasf.us2.list-manage.com/profile?u=f61cd5fab09d8a8362ea924a7&id=942833b800&e=be5e943cfb&c=2f3fffa5a1', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
# No attachments found.
#
# 🤖 ML DETECTION (Fallback):
#     ✅ ML Model detected LEGITIMATE (Confidence: 84.43%)
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-18.eml
# From: metamask-updates-action@netwrksecurity.com
# Subject: Alerts
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-19.eml
# From: ksimser@rmh.org
# Subject: AW
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
#   - https://t.me/+pGV6aj_DOkQ1OWI0
# Querying PhishTank for: https://t.me/+pGV6aj_DOkQ1OWI0
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:16+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a5c6854e6.54483264'}, 'results': {'url': 'https://t.me/ pGV6aj_DOkQ1OWI0', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - https://t.me/+pGV6aj_DOkQ1OWI0
# Querying PhishTank for: https://t.me/+pGV6aj_DOkQ1OWI0
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:17+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53a5dc9e275.85100063'}, 'results': {'url': 'https://t.me/ pGV6aj_DOkQ1OWI0', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
# No attachments found.
#
# 🤖 ML DETECTION (Fallback):
#     ✅ ML Model detected LEGITIMATE (Confidence: 58.74%)
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-2.eml
# From: postmaster@digitalmashreq.mg.tdi.tc
# Subject: Confirm Your Mashreq Email Now For Your Security (MOVE TO INBOX)
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-20.eml
# From: herb@southernheritagecc.com
# Subject: Earn XLM by staking your assets
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
#   - Stellar.org
# Querying PhishTank for: Stellar.org
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:19+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a5f8a8dc1.68432145'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
#   - discretion.Safety
# Querying PhishTank for: discretion.Safety
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:20+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a60d65ee6.06223517'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
#   - reserved.No
# Querying PhishTank for: reserved.No
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:21+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a619199e8.06015300'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
#   - Stellar.org
# Querying PhishTank for: Stellar.org
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:22+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a62504e28.48164814'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
#   - discretion.Safety
# Querying PhishTank for: discretion.Safety
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:23+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a630cb618.43995920'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
#   - reserved.No
# Querying PhishTank for: reserved.No
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:24+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a6469a723.06196155'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
# No attachments found.
#
# 🤖 ML DETECTION (Fallback):
#     ✅ ML Model detected LEGITIMATE (Confidence: 59.80%)
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-21.eml
# From: newsmail@app9l.serenitepure.fr
# Subject: Het begint weer warm te worden
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-22.eml
# From: team@exodus.com
# Subject: Important changes to your Exodus wallet
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
#   - Exodus.com/identify
# Querying PhishTank for: Exodus.com/identify
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:26+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a66024271.17783281'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
#   - Exodus.com/identify
# Querying PhishTank for: Exodus.com/identify
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:33:26+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53a66b25064.16632364'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
# No attachments found.
#
# 🤖 ML DETECTION (Fallback):
#     ⚠️ ML Model detected PHISHING (Confidence: 51.35%)
#
# 🎯 FINAL VERDICT: MALICIOUS
#     🚨 EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68c53aa4d0b780.24432530'}, 'results': {'url': 'https://opensea.io/collection/the-girl-with-a-pearl-earring', 'in_database': False}}
#     ❓ URL not in database - requires ML analysis.
#   - www.thesapphirestudio.com
# Querying PhishTank for: www.thesapphirestudio.com
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:34:29+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53aa5a45818.90184881'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
# No attachments found.
#
# 🤖 ML DETECTION (Fallback):
#     ⚠️ ML Model detected PHISHING (Confidence: 56.31%)
#
# 🎯 FINAL VERDICT: MALICIOUS
#     🚨 EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# 📧 File: sample-88.eml
# From: mercadopagommo@hotmail.com
# Subject: Alerta de seguranca: verifique o acesso a sua conta do Mercado Pago Protocolo: 801002860
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-89.eml
# From: yssnsn@minecraftray.ru
# Subject: Hello how are you? Do you like beauty girl??
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
#   - have.Dating
# Querying PhishTank for: have.Dating
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-13T09:34:31+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68c53aa71f4962.82423822'}, 'errortext': 'You have supplied a malformed URL'}
#     ❓ URL not in database - requires ML analysis.
# No attachments found.
#
# 🤖 ML DETECTION (Fallback):
#     ⚠️ ML Model detected PHISHING (Confidence: 58.61%)
#
# 🎯 FINAL VERDICT: MALICIOUS
#     🚨 EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# 📧 File: sample-9.eml
# From: noreply@firesonic.ca
# Subject: You sent 0.79 ETH via Ethereum network
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-90.eml
# From: contato@mercadolivre.com.br
# Subject: BLOQUEAMOS UM ACESSO SUSPEITO - PROTOCOLO: 283890577.
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-91.eml
# From: newsmail@appHA.serenitepure.fr
# Subject: Ik hoop dat je die foto's leuk vindt: (8 foto's), (10 video's)..
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-92.eml
# From: k4rlanauroski@gmail.com
# Subject: (No Subject)
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# Attachments found:
#   ✅ Attachment is safe: attachments\nzHc3RSHv.pdf
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-93.eml
# From: naoresponder@mercadolivre.com.br
# Subject: Rodrigo Ferreira Peixoto, você removeu seu método de duas etapas?
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-94.eml
# From: Nellie.Horton@broadband.vi
# Subject: We have updated our Privacy
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-95.eml
# From: 7wq1vg3kn9woejk4@emails.gorgias.com
# Subject: FWD: All unverified accounts will be suspended on 10/30/2022.
#  2hwpexn64bmc7qrzvo0kyduajlgf3598
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-96.eml
# From: jodykrier60@gmail.com
# Subject: ‼️🔔 Information in attachment
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# Attachments found:
#   ✅ Attachment is safe: attachments\3spyWy0D.pdf
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-97.eml
# From: 051137@mca.sendmaster.online
# Subject: Bloqueio de conta 532543326 - ID YDW6NQYHNY
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-98.eml
# From: duckd@krasn-zoo.ru
# Subject: I am so lonely and so sexy. Why wouldn’t you write me?
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: sample-99.eml
# From: newsmail@appJv.serenitepure.fr
# Subject: Veel nieuwe aanmeldingen deze week
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# No attachments found.
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
#
# 📧 File: test_sample_message.eml
# From: mlemos@acm.org
# Subject: Testing Manuel Lemos' MIME E-mail composing and sending PHP class: HTML message
# 🔍 BLACKLIST ANALYSIS:
# Extracted URLs:
# Attachments found:
#   ✅ Attachment is safe: attachments\logo.gif
#   ✅ Attachment is safe: attachments\background.gif
#   ✅ Attachment is safe: attachments\attachment.txt
#
# 🎯 FINAL VERDICT: SAFE
#     ✅ Email appears to be safe
#
# ------------------------------------------------------------
